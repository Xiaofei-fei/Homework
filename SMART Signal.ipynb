# %%
#导入必要的包
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import time
import datetime
from pandas import ExcelWriter
import seaborn as sns

# %%
# 读取所需文件
file=r'C:\Users\Administrator\Desktop\SMART Signal作业\Boone 0101-20081201（0时-12时）.xlsx'
detector_data=pd.read_excel(file,sheet_name='detector data')
signal_data=pd.read_excel(file,sheet_name='signal data')
relationship=pd.read_excel(file,sheet_name='relationship')
count=pd.read_excel(file,sheet_name='count')
# relationship

# %%
detector_data.head()
# Out:
#         ID  TimeStamps       TimeStamp  DetectorID  TimeDuration     Speed  \
# 0  6570969      31.000  81201000031000          35         0.281  3.558719
# 1  6570970      38.734  81201000038734          36         0.359  2.785515
# 2  6570971     123.531  81201000203531          36         0.265  3.773585
# 3  6570972     132.296  81201000212296          36         0.313  3.194888
# 4  3703282     153.890  81201000233890          34         0.266  3.759398
#
#                       Time
# 0  2008-12-01 00:00:31.000
# 1  2008-12-01 00:00:38.734
# 2  2008-12-01 00:02:03.531
# 3  2008-12-01 00:02:12.296
# 4  2008-12-01 00:02:33.890

# %%
signal_data.head()
# Out:
#        ID  TimeStamps       TimeStamp  SecondStamp Status  PhaseID  \
# 0  233343     175.546  81201000255546       255546      Y        2
# 1  233344     175.546  81201000255546       255546      Y        6
# 2  233345     182.531  81201000302531       302531      G        4
# 3  233346     182.531  81201000302531       302531      G        8
# 4  233347     192.531  81201000312531       312531      Y        4
#
#    TimeDuration                     Time
# 0         5.485  2008-12-01 00:02:55.546
# 1         5.485  2008-12-01 00:02:55.546
# 2        10.000  2008-12-01 00:03:02.531
# 3        10.000  2008-12-01 00:03:02.531
# 4         3.500  2008-12-01 00:03:12.531

# %%
#统计第一相位各红绿灯周期内的车辆数
detector_road1=[]
for i in range(detector_data.shape[0]):
    if((detector_data.DetectorID[i])==5):
        detector_road1.append(detector_data.TimeStamps[i])
signal1=[]
time1=[]
for i in range(signal_data.shape[0]):
    if(signal_data.PhaseID[i]==1):
        signal1.append(signal_data.TimeStamps[i])
        time1.append(signal_data.Time[i])
g1=[]
g2=[]
for i in range(signal_data.shape[0]):
    if(signal_data.Status[i]=='G' and signal_data.PhaseID[i]==1):
        g1.append(signal_data.TimeStamps[i])
        g2.append((signal_data.TimeStamps[i])+(signal_data.TimeDuration[i]))
y1=[]
y2=[]
for i in range(signal_data.shape[0]):
    if((signal_data.Status[i]=='Y') and (signal_data.PhaseID[i]==1)):
        y1.append(signal_data.TimeStamps[i])
        y2.append(((signal_data.TimeStamps[i])+(signal_data.TimeDuration[i])))
r1=[]
r2=[]
for i in range(len(y2)):
    r1.append(y2[i])
for i in range(1,len(g1)):
    r2.append(g1[i])
countg={}
for j in range(len(g1)):
    countg[j]=0
    for i in range(len(detector_road1)):
        if((detector_road1[i]>g1[j])&(detector_road1[i]<g2[j])):
            countg[j]+=1
county={}
for j in range(len(y1)):
    county[j]=0
    for i in range(len(detector_road1)):
        if((detector_road1[i]>y1[j])&(detector_road1[i]<y2[j])):
            county[j]+=1
countr={}
for j in range(len(r1)-1):
    countr[j]=0
    for i in range(len(detector_road1)):
        if((detector_road1[i]>r1[j])&(detector_road1[i]<r2[j])):
            countr[j]+=1

# %%
#统计第一相位个周期内信号灯的持续时间
rf=[]
for i in range(len(r1)-1):
    rf.append(r2[i]-r1[i])
gf=[]
for i in range(signal_data.shape[0]):
    if((signal_data.Status[i]=='G') and (signal_data.PhaseID[i]==1)):
        gf.append(signal_data.TimeDuration[i])
yf=[]
for i in range(signal_data.shape[0]):
    if((signal_data.Status[i]=='Y') and (signal_data.PhaseID[i]==1)):
        yf.append(signal_data.TimeDuration[i])
totalg = 0
for ele in range(0, len(gf)):
    totalg = totalg + gf[ele]
totaly = 0
for ele in range(0, len(yf)):
    totaly = totaly + yf[ele]
totalr = 0
for ele in range(0, len(rf)):
    totalr = totalr + rf[ele]

# %%
detector_road2=[]
for i in range(detector_data.shape[0]):
    if((detector_data.DetectorID[i]==30) or (detector_data.DetectorID[i]==31) or (detector_data.DetectorID[i]==32)):
        detector_road2.append(detector_data.TimeStamps[i])
signal2=[]
for i in range(signal_data.shape[0]):
    if(signal_data.PhaseID[i]==2):
        signal2.append(signal_data.TimeStamps[i])
g12=[]
g22=[]
for i in range(signal_data.shape[0]):
    if(signal_data.Status[i]=='G' and signal_data.PhaseID[i]==2):
        g12.append(signal_data.TimeStamps[i])
        g22.append(((signal_data.TimeStamps[i])+(signal_data.TimeDuration[i])))
y12=[]
y22=[]
for i in range(signal_data.shape[0]):
    if((signal_data.Status[i]=='Y') and (signal_data.PhaseID[i]==2)):
        y12.append(signal_data.TimeStamps[i])
        y22.append(((signal_data.TimeStamps[i])+(signal_data.TimeDuration[i])))
r12=[]
r22=[]
for i in range(len(y22)):
    r12.append(y22[i])
for i in range(1,len(g12)):
    r22.append(g12[i])
countg2={}
for j in range(len(g12)):
    countg2[j]=0
    for i in range(len(detector_road2)):
        if((detector_road2[i]>g12[j])&(detector_road2[i]<g22[j])):
            countg2[j]+=1
county2={}
for j in range(len(y12)):
    county2[j]=0
    for i in range(len(detector_road2)):
        if((detector_road2[i]>y12[j])&(detector_road2[i]<y22[j])):
            county2[j]+=1
countr2={}
for j in range(len(r12)-2):
    countr2[j]=0
    for i in range(len(detector_road2)):
        if((detector_road2[i]>r12[j])&(detector_road2[i]<r22[j])):
            countr2[j]+=1

# %%
rs=[]
for i in range(len(r12)-2):
    rs.append(r22[i]-r12[i])
gs=[]
for i in range(signal_data.shape[0]):
    if((signal_data.Status[i]=='G') and (signal_data.PhaseID[i]==2)):
        gs.append(signal_data.TimeDuration[i])
ys=[]
for i in range(signal_data.shape[0]):
    if((signal_data.Status[i]=='Y') and (signal_data.PhaseID[i]==2)):
        ys.append(signal_data.TimeDuration[i])
totalg2 = 0
for ele in range(0, len(gs)):
    totalg2 = totalg2 + gs[ele]
totaly2 = 0
for ele in range(0, len(ys)):
    totaly2 = totaly2 + ys[ele]
totalr2 = 0
for ele in range(0, len(rs)):
    totalr2 = totalr2 + rs[ele]

# %%
detector_road3=[]
for i in range(detector_data.shape[0]):
    if((detector_data.DetectorID[i]==14)):
        detector_road3.append(detector_data.TimeStamps[i])
signal3=[]
for i in range(signal_data.shape[0]):
    if(signal_data.PhaseID[i]==3):
        signal3.append(signal_data.TimeStamps[i])
g13=[]
g23=[]
for i in range(signal_data.shape[0]):
    if(signal_data.Status[i]=='G' and signal_data.PhaseID[i]==3):
        g13.append(signal_data.TimeStamps[i])
        g23.append(((signal_data.TimeStamps[i])+(signal_data.TimeDuration[i])))
y13=[]
y23=[]
for i in range(signal_data.shape[0]):
    if((signal_data.Status[i]=='Y') and (signal_data.PhaseID[i]==3)):
        y13.append(signal_data.TimeStamps[i])
        y23.append(((signal_data.TimeStamps[i])+(signal_data.TimeDuration[i])))
r13=[]
r23=[]
for i in range(len(y23)):
    r13.append(y23[i])
for i in range(1,len(g13)):
    r23.append(g13[i])
countg3={}
for j in range(len(g13)):
    countg3[j]=0
    for i in range(len(detector_road3)):
        if((detector_road3[i]>g13[j])&(detector_road3[i]<g23[j])):
            countg3[j]+=1
county3={}
for j in range(len(y13)):
    county3[j]=0
    for i in range(len(detector_road3)):
        if((detector_road3[i]>y13[j])&(detector_road3[i]<y23[j])):
            county3[j]+=1
countr3={}
for j in range(len(r13)-1):
    countr3[j]=0
    for i in range(len(detector_road3)):
        if((detector_road3[i]>r13[j])&(detector_road3[i]<r23[j])):
            countr3[j]+=1

# %%
rt=[]
for i in range(len(r13)-1):
    rt.append(r23[i]-r13[i])
gt=[]
for i in range(signal_data.shape[0]):
    if((signal_data.Status[i]=='G') and (signal_data.PhaseID[i]==3)):
        gt.append(signal_data.TimeDuration[i])
yt=[]
for i in range(signal_data.shape[0]):
    if((signal_data.Status[i]=='Y') and (signal_data.PhaseID[i]==3)):
        yt.append(signal_data.TimeDuration[i])
totalg3 = 0
for ele in range(0, len(gt)):
    totalg3 = totalg3 + gt[ele]
totaly3 = 0
for ele in range(0, len(yt)):
    totaly3 = totaly3 + yt[ele]
totalr3 = 0
for ele in range(0, len(rt)):
    totalr3 = totalr3 + rt[ele]

# %%
detector_road4=[]
for i in range(detector_data.shape[0]):
    if((detector_data.DetectorID[i]==16)or(detector_data.DetectorID[i]==17)or(detector_data.DetectorID[i]==18)):
        detector_road4.append(detector_data.TimeStamps[i])
signal4=[]
for i in range(signal_data.shape[0]):
    if(signal_data.PhaseID[i]==4):
        signal4.append(signal_data.TimeStamps[i])
g14=[]
g24=[]
for i in range(signal_data.shape[0]):
    if(signal_data.Status[i]=='G' and signal_data.PhaseID[i]==4):
        g14.append(signal_data.TimeStamps[i])
        g24.append(((signal_data.TimeStamps[i])+(signal_data.TimeDuration[i])))
y14=[]
y24=[]
for i in range(signal_data.shape[0]):
    if((signal_data.Status[i]=='Y') and (signal_data.PhaseID[i]==4)):
        y14.append(signal_data.TimeStamps[i])
        y24.append(((signal_data.TimeStamps[i])+(signal_data.TimeDuration[i])))
r14=[]
r24=[]
for i in range(len(y24)):
    r14.append(y24[i])
for i in range(1,len(g14)):
    r24.append(g14[i])
countg4={}
for j in range(len(g14)):
    countg4[j]=0
    for i in range(len(detector_road4)):
        if((detector_road4[i]>g14[j])&(detector_road4[i]<g24[j])):
            countg4[j]+=1
county4={}
for j in range(len(y14)):
    county4[j]=0
    for i in range(len(detector_road4)):
        if((detector_road4[i]>y14[j])&(detector_road4[i]<y24[j])):
            county4[j]+=1
countr4={}
for j in range(len(r14)-1):
    countr4[j]=0
    for i in range(len(detector_road4)):
        if((detector_road4[i]>r14[j])&(detector_road4[i]<r24[j])):
            countr4[j]+=1

# %%
rf1=[]
for i in range(len(r14)-1):
    rf1.append(r24[i]-r14[i])
gf1=[]
for i in range(signal_data.shape[0]):
    if((signal_data.Status[i]=='G') and (signal_data.PhaseID[i]==4)):
        gf1.append(signal_data.TimeDuration[i])
yf1=[]
for i in range(signal_data.shape[0]):
    if((signal_data.Status[i]=='Y') and (signal_data.PhaseID[i]==4)):
        yf1.append(signal_data.TimeDuration[i])
totalg4 = 0
for ele in range(0, len(gf1)):
    totalg4 = totalg4 + gf1[ele]
totaly4 = 0
for ele in range(0, len(yf1)):
    totaly4 = totaly4 + yf1[ele]
totalr4= 0
for ele in range(0, len(rf1)):
    totalr4 = totalr4 + rf1[ele]

# %%
detector_road5=[]
for i in range(detector_data.shape[0]):
    if((detector_data.DetectorID[i]==6)):
        detector_road5.append(detector_data.TimeStamps[i])
signal5=[]
for i in range(signal_data.shape[0]):
    if(signal_data.PhaseID[i]==5):
        signal5.append(signal_data.TimeStamps[i])
g15=[]
g25=[]
for i in range(signal_data.shape[0]):
    if(signal_data.Status[i]=='G' and signal_data.PhaseID[i]==5):
        g15.append(signal_data.TimeStamps[i])
        g25.append(((signal_data.TimeStamps[i])+(signal_data.TimeDuration[i])))
y15=[]
y25=[]
for i in range(signal_data.shape[0]):
    if((signal_data.Status[i]=='Y') and (signal_data.PhaseID[i]==5)):
        y15.append(signal_data.TimeStamps[i])
        y25.append(((signal_data.TimeStamps[i])+(signal_data.TimeDuration[i])))
r15=[]
r25=[]
for i in range(len(y25)):
    r15.append(y25[i])
for i in range(1,len(g15)):
    r25.append(g15[i])
countg5={}
for j in range(len(g15)):
    countg5[j]=0
    for i in range(len(detector_road5)):
        if((detector_road5[i]>g15[j])&(detector_road5[i]<g25[j])):
            countg5[j]+=1
county5={}
for j in range(len(y15)):
    county5[j]=0
    for i in range(len(detector_road5)):
        if((detector_road5[i]>y15[j])&(detector_road5[i]<y25[j])):
            county5[j]+=1
countr5={}
for j in range(len(r15)-1):
    countr5[j]=0
    for i in range(len(detector_road5)):
        if((detector_road5[i]>r15[j])&(detector_road5[i]<r25[j])):
            countr5[j]+=1

# %%
rf2=[]
for i in range(len(r15)-1):
    rf2.append(r25[i]-r15[i])
gf2=[]
for i in range(signal_data.shape[0]):
    if((signal_data.Status[i]=='G') and (signal_data.PhaseID[i]==5)):
        gf2.append(signal_data.TimeDuration[i])
yf2=[]
for i in range(signal_data.shape[0]):
    if((signal_data.Status[i]=='Y') and (signal_data.PhaseID[i]==5)):
        yf2.append(signal_data.TimeDuration[i])
totalg5 = 0
for ele in range(0, len(gf2)):
    totalg5 = totalg5 + gf2[ele]
totaly5 = 0
for ele in range(0, len(yf2)):
    totaly5 = totaly5 + yf2[ele]
totalr5= 0
for ele in range(0, len(rf2)):
    totalr5 = totalr5 + rf2[ele]

# %%
detector_road6=[]
for i in range(detector_data.shape[0]):
    if((detector_data.DetectorID[i]==25) or (detector_data.DetectorID[i]==26) or (detector_data.DetectorID[i]==25)):
        detector_road6.append(detector_data.TimeStamps[i])
signal6=[]
for i in range(signal_data.shape[0]):
    if(signal_data.PhaseID[i]==6):
        signal6.append(signal_data.TimeStamps[i])
g16=[]
g26=[]
for i in range(signal_data.shape[0]):
    if(signal_data.Status[i]=='G' and signal_data.PhaseID[i]==6):
        g16.append(signal_data.TimeStamps[i])
        g26.append(((signal_data.TimeStamps[i])+(signal_data.TimeDuration[i])))
y16=[]
y26=[]
for i in range(signal_data.shape[0]):
    if((signal_data.Status[i]=='Y') and (signal_data.PhaseID[i]==6)):
        y16.append(signal_data.TimeStamps[i])
        y26.append(((signal_data.TimeStamps[i])+(signal_data.TimeDuration[i])))
r16=[]
r26=[]
for i in range(len(y26)):
    r16.append(y26[i])
for i in range(1,len(g16)):
    r26.append(g16[i])
countg6={}
for j in range(len(g16)):
    countg6[j]=0
    for i in range(len(detector_road6)):
        if((detector_road6[i]>g16[j])&(detector_road6[i]<g26[j])):
            countg6[j]+=1
county6={}
for j in range(len(y16)):
    county6[j]=0
    for i in range(len(detector_road6)):
        if((detector_road6[i]>y16[j])&(detector_road6[i]<y26[j])):
            county6[j]+=1
countr6={}
for j in range(len(r16)-2):
    countr6[j]=0
    for i in range(len(detector_road6)):
        if((detector_road6[i]>r16[j])&(detector_road6[i]<r26[j])):
            countr6[j]+=1

# %%
rs2=[]
for i in range(len(r16)-2):
    rs2.append(r26[i]-r16[i])
gs2=[]
for i in range(signal_data.shape[0]):
    if((signal_data.Status[i]=='G') and (signal_data.PhaseID[i]==6)):
        gs2.append(signal_data.TimeDuration[i])
ys2=[]
for i in range(signal_data.shape[0]):
    if((signal_data.Status[i]=='Y') and (signal_data.PhaseID[i]==6)):
        ys2.append(signal_data.TimeDuration[i])
totalg6 = 0
for ele in range(0, len(gs2)):
    totalg6 = totalg6 + gs2[ele]
totaly6 = 0
for ele in range(0, len(ys2)):
    totaly6 = totaly6 + ys2[ele]
totalr6 = 0
for ele in range(0, len(rs2)):
    totalr6 = totalr6 + rs2[ele]

# %%
detector_road7=[]
for i in range(detector_data.shape[0]):
    if((detector_data.DetectorID[i]==20) ):
        detector_road7.append(detector_data.TimeStamps[i])
signal7=[]
for i in range(signal_data.shape[0]):
    if(signal_data.PhaseID[i]==7):
        signal7.append(signal_data.TimeStamps[i])
g17=[]
g27=[]
for i in range(signal_data.shape[0]):
    if(signal_data.Status[i]=='G' and signal_data.PhaseID[i]==7):
        g17.append(signal_data.TimeStamps[i])
        g27.append(((signal_data.TimeStamps[i])+(signal_data.TimeDuration[i])))
y17=[]
y27=[]
for i in range(signal_data.shape[0]):
    if((signal_data.Status[i]=='Y') and (signal_data.PhaseID[i]==7)):
        y17.append(signal_data.TimeStamps[i])
        y27.append(((signal_data.TimeStamps[i])+(signal_data.TimeDuration[i])))
r17=[]
r27=[]
for i in range(len(y27)):
    r17.append(y27[i])
for i in range(1,len(g17)):
    r27.append(g17[i])
countg7={}
for j in range(len(g17)):
    countg7[j]=0
    for i in range(len(detector_road7)):
        if((detector_road7[i]>g17[j])&(detector_road7[i]<g27[j])):
            countg7[j]+=1
county7={}
for j in range(len(y17)):
    county7[j]=0
    for i in range(len(detector_road7)):
        if((detector_road7[i]>y17[j])&(detector_road7[i]<y27[j])):
            county7[j]+=1
countr7={}
for j in range(len(r17)-2):
    countr7[j]=0
    for i in range(len(detector_road7)):
        if((detector_road7[i]>r17[j])&(detector_road7[i]<r27[j])):
            countr7[j]+=1

# %%
rs3=[]
for i in range(len(r17)-2):
    rs3.append(r27[i]-r17[i])
gs3=[]
for i in range(signal_data.shape[0]):
    if((signal_data.Status[i]=='G') and (signal_data.PhaseID[i]==7)):
        gs3.append(signal_data.TimeDuration[i])
ys3=[]
for i in range(signal_data.shape[0]):
    if((signal_data.Status[i]=='Y') and (signal_data.PhaseID[i]==7)):
        ys3.append(signal_data.TimeDuration[i])
totalg7 = 0
for ele in range(0, len(gs3)):
    totalg7 = totalg7 + gs3[ele]
totaly7 = 0
for ele in range(0, len(ys3)):
    totaly7 = totaly7 + ys3[ele]
totalr7 = 0
for ele in range(0, len(rs3)):
    totalr7 = totalr7 + rs3[ele]

# %%
detector_road8=[]
for i in range(detector_data.shape[0]):
    if((detector_data.DetectorID[i]==19) or (detector_data.DetectorID[i]==23) or (detector_data.DetectorID[i]==24)):
        detector_road8.append(detector_data.TimeStamps[i])
signal8=[]
for i in range(signal_data.shape[0]):
    if(signal_data.PhaseID[i]==8):
        signal8.append(signal_data.TimeStamps[i])
g18=[]
g28=[]
for i in range(signal_data.shape[0]):
    if(signal_data.Status[i]=='G' and signal_data.PhaseID[i]==8):
        g18.append(signal_data.TimeStamps[i])
        g28.append(((signal_data.TimeStamps[i])+(signal_data.TimeDuration[i])))
y18=[]
y28=[]
for i in range(signal_data.shape[0]):
    if((signal_data.Status[i]=='Y') and (signal_data.PhaseID[i]==8)):
        y18.append(signal_data.TimeStamps[i])
        y28.append(((signal_data.TimeStamps[i])+(signal_data.TimeDuration[i])))
r18=[]
r28=[]
for i in range(len(y28)):
    r18.append(y28[i])
for i in range(1,len(g18)):
    r28.append(g18[i])
countg8={}
for j in range(len(g18)):
    countg8[j]=0
    for i in range(len(detector_road8)):
        if((detector_road8[i]>g18[j])&(detector_road8[i]<g28[j])):
            countg8[j]+=1
county8={}
for j in range(len(y18)):
    county8[j]=0
    for i in range(len(detector_road8)):
        if((detector_road8[i]>y18[j])&(detector_road8[i]<y28[j])):
            county8[j]+=1
countr8={}
for j in range(len(r18)-1):
    countr8[j]=0
    for i in range(len(detector_road8)):
        if((detector_road8[i]>r18[j])&(detector_road8[i]<r28[j])):
            countr8[j]+=1

# %%
re=[]
for i in range(len(r18)-1):
    re.append(r28[i]-r18[i])
ge=[]
for i in range(signal_data.shape[0]):
    if((signal_data.Status[i]=='G') and (signal_data.PhaseID[i]==8)):
        ge.append(signal_data.TimeDuration[i])
ye=[]
for i in range(signal_data.shape[0]):
    if((signal_data.Status[i]=='Y') and (signal_data.PhaseID[i]==8)):
        ye.append(signal_data.TimeDuration[i])
totalg8 = 0
for ele in range(0, len(ge)):
    totalg8 = totalg8 + ge[ele]
totaly8 = 0
for ele in range(0, len(ye)):
    totaly8 = totaly8 + ye[ele]
totalr8 = 0
for ele in range(0, len(re)):
    totalr8 = totalr8 + re[ele]

# %%
#绘制各相位时间内的车辆图
#绘制可视化图像
yy1=np.array([331,7374,78,450,304,2725,212,220])
yy2=np.array([34,264,4,19,26,138,20,29])
yy3=np.array([153,9289,142,563,221,3930,162,557])
labels=['First','Second','Third','Forth','Fifth','Sixth','Seventh','Eigth']

# %%
# %matplotlib
plt.bar(labels, yy1, color='green', label='Green')
plt.bar(labels, yy2, bottom=yy1, color='yellow', label='Yellow')
plt.bar(labels, yy3, bottom=yy1+yy2, color='red', label='Red')
plt.rcParams['font.sans-serif']=['Microsoft YaHei']
plt.rcParams['axes.unicode_minus']=False
plt.ylabel('单一相位车辆数')
plt.xlabel('相位数')
plt.legend()
# Out:
# Using matplotlib backend: Qt5Agg

# %%
#绘制可视化图像
gg1=np.array([totalg,totalg2,totalg3,totalg4,totalg5,totalg6,totalg7,totalg8])
gg2=np.array([totaly,totaly2,totaly3,totaly4,totaly5,totaly6,totaly7,totaly8])
gg3=np.array([totalr,totalr2,totalr3,totalr4,totalr5,totalr6,totalr7,totalr8])
labels=['First','Second','Third','Forth','Fifth','Sixth','Seventh','Eigth']

# %%
# %matplotlib
plt.barh(labels, gg1, color='green', label='Green')
plt.barh(labels, gg2, left=gg1, color='yellow', label='Yellow')
plt.barh(labels, gg3,left=gg1+gg2, color='red', label='Red')
plt.rcParams['font.sans-serif']=['Microsoft YaHei']
plt.rcParams['axes.unicode_minus']=False
plt.xlabel('单一相位信号灯时长(秒)')
plt.ylabel('相位数')
plt.legend()
# Out:
# Using matplotlib backend: Qt5Agg

# %%
#绘制可视化图像
rr1=np.array([gf[100],gs[100],gt[100],gf1[100],gf2[100],gs2[100],gs3[100],ge[100]])
rr2=np.array([yf[100],ys[100],yt[100],yf1[100],yf2[100],ys2[100],ys3[100],ye[100]])
rr3=np.array([rf[100],rs[100],rt[100],rf1[100],rf2[100],rs2[100],rs3[100],re[100]])
labels=['First','Second','Third','Forth','Fifth','Sixth','Seventh','Eigth']

# %%
# %matplotlib
plt.barh(labels, rr1, color='green', label='Green')
plt.barh(labels, rr2, left=rr1, color='yellow', label='Yellow')
plt.barh(labels, rr3,left=rr1+rr2, color='red', label='Red')
plt.rcParams['font.sans-serif']=['Microsoft YaHei']
plt.rcParams['axes.unicode_minus']=False
plt.xlabel('单一相位信号灯时长(秒)')
plt.ylabel('相位数')
plt.legend()
# Out:
# Using matplotlib backend: Qt5Agg

# %%
Time1=[]
Countg=[]
n1=[]
for i in range(len(g1)):
    time1[i]
    countg[i]
    Time1.append(time1[i])
    n1.append(i)
    Countg.append(countg[i])

# %%
fig=plt.bar(n1,Countg)

# %%
#绘制当前信号配时图
Time1=[]
County=[]
n11=[]
for i in range(len(y1)):
    time1[i]
    county[i]
    Time1.append(time1[i])
    n11.append(i)
    County.append(county[i])
plt.bar(n11,County)
# Out:
# <BarContainer object of 158 artists>
